# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1gStQLaKA1uxenhqjKaEIT7ZFecqkL3Fz/view?usp=drive_link"

# %%
type(url)
# Out:
# str

# %%
file_id =url.split("/")[-2]
file_id
# Out:
# '1gStQLaKA1uxenhqjKaEIT7ZFecqkL3Fz'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1gStQLaKA1uxenhqjKaEIT7ZFecqkL3Fz
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1gStQLaKA1uxenhqjKaEIT7ZFecqkL3Fz&confirm=t&uuid=edf124e7-3535-4620-b479-e1a3ddfd963d
# To: c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\research\data.zip
# 100%|██████████| 91.0M/91.0M [00:30<00:00, 3.02MB/s]
# 'data.zip'
