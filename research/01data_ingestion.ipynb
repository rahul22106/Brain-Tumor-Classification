# %%
import os
import sys

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path 
    source_url: str
    local_data_file: Path
    unzip_dir: Path 
    train_data_dir: Path
    test_data_dir: Path

# %%
from pathlib import Path

CONFIG_FILE_PATH = Path("config/config.yaml")
PARAMS_FILE_PATH = Path("params.yaml")

# %%
from BT_Classification.constants import *
from BT_Classification.utils.common import read_yaml,create_directories
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 # from BT_Classification.constants import *
# ----> 2 from BT_Classification.utils.common import read_yaml,create_directories
#
# ModuleNotFoundError: No module named 'BT_Classification'
