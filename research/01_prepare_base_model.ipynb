# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\shipr\\OneDrive\\Documents\\project\\Brain-tumor-Classification\\research'

# %%
os.chdir("../")

# %%
from pathlib import Path
from dataclasses import dataclass
@dataclass(frozen=True)
class PrepareBaseModelConfig:
    """Configuration for Base Model Preparation"""
    root_dir: Path
    base_model_path: Path
    updated_base_model_path: Path
    params_image_size: list
    params_learning_rate: float
    params_include_top: bool
    params_weights: str
    params_classes: int

# %%
from BT_Classification.constants import *
from BT_Classification.utils.common import read_yaml, create_directories

# %%
def get_prepare_base_model_config(self) -> PrepareBaseModelConfig:
        """
        Get Base Model Preparation configuration
        
        Returns:
            PrepareBaseModelConfig: Configuration object for base model
        """
        config = self.config.prepare_base_model
        
        create_directories([config.root_dir])
        
        prepare_base_model_config = PrepareBaseModelConfig(
            root_dir=Path(config.root_dir),
            base_model_path=Path(config.base_model_path),
            updated_base_model_path=Path(config.updated_base_model_path),
            params_image_size=self.params.IMAGE_SIZE,
            params_learning_rate=self.params.LEARNING_RATE,
            params_include_top=self.params.INCLUDE_TOP,
            params_weights=self.params.WEIGHTS,
            params_classes=self.params.CLASSES
        )
        
        return prepare_base_model_config

# %%
from BT_Classification.constants import *
from BT_Classification.utils.common import read_yaml, create_directories
from BT_Classification.entity import (
    DataIngestionConfig,PrepareBaseModelConfig
)


class ConfigurationManager:
    """
    Configuration Manager to read and manage all configurations
    """
    
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        
        # Create artifacts root directory
        create_directories([self.config.artifacts_root])
    
    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        """
        Get Data Ingestion configuration
        
        Returns:
            DataIngestionConfig: Configuration object for data ingestion
        """
        config = self.config.data_ingestion
        
        # Create root directory for data ingestion
        create_directories([config.root_dir])
        
        data_ingestion_config = DataIngestionConfig(
            root_dir=Path(config.root_dir),
            source_URL=config.source_URL,
            local_data_file=Path(config.local_data_file),
            unzip_dir=Path(config.unzip_dir),
            train_data_dir=Path(config.train_data_dir),
            test_data_dir=Path(config.test_data_dir)
        )
        
        return data_ingestion_config
    
     
    def get_prepare_base_model_config(self) -> PrepareBaseModelConfig:
        """
        Get Base Model Preparation configuration
        
        Returns:
            PrepareBaseModelConfig: Configuration object for base model
        """
        config = self.config.prepare_base_model
        
        create_directories([config.root_dir])
        
        prepare_base_model_config = PrepareBaseModelConfig(
            root_dir=Path(config.root_dir),
            base_model_path=Path(config.base_model_path),
            updated_base_model_path=Path(config.updated_base_model_path),
            params_image_size=self.params.IMAGE_SIZE,
            params_learning_rate=self.params.LEARNING_RATE,
            params_include_top=self.params.INCLUDE_TOP,
            params_weights=self.params.WEIGHTS,
            params_classes=self.params.CLASSES
        )
        
        return prepare_base_model_config

# %%
class DataIngestionTrainingPipeline:
    """
    Pipeline for Data Ingestion Stage
    """
    def __init__(self):
        pass
    
    def main(self):
        """Execute data ingestion pipeline"""
        config = ConfigurationManager()
        data_ingestion_config = config.get_data_ingestion_config()
        data_ingestion = DataIngestion(config=data_ingestion_config)
        data_ingestion.initiate_data_ingestion()

# %%
from BT_Classification import logger
from BT_Classification.pipeline import PrepareBaseModelTrainingPipeline
STAGE_NAME = "Prepare Base Model Stage"
try:
    logger.info(f"\n{'='*70}")
    logger.info(f">>>>>> stage {STAGE_NAME} started <<<<<<")
    logger.info(f"{'='*70}\n")
    
    prepare_base_model = PrepareBaseModelTrainingPipeline()
    prepare_base_model.main()
    
    logger.info(f"\n{'='*70}")
    logger.info(f">>>>>> stage {STAGE_NAME} completed <<<<<<")
    logger.info(f"{'='*70}\n\n")
    
except Exception as e:
    logger.exception(e)
    raise e
# Out:
# [2025-11-13 12:13:50,231: INFO: 839453329:
# ======================================================================]
# [2025-11-13 12:13:50,235: INFO: 839453329: >>>>>> stage Prepare Base Model Stage started <<<<<<]
# [2025-11-13 12:13:50,238: INFO: 839453329: ======================================================================
# ]
# [2025-11-13 12:13:50,248: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-11-13 12:13:50,255: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-11-13 12:13:50,258: INFO: common: Created directory at: artifacts]
# [2025-11-13 12:13:50,261: INFO: common: Created directory at: artifacts/prepare_base_model]
# [2025-11-13 12:13:50,263: INFO: stage_01_prepare_base_model: ======================================================================]
# [2025-11-13 12:13:50,265: INFO: stage_01_prepare_base_model: STARTING BASE MODEL PREPARATION]
# [2025-11-13 12:13:50,267: INFO: stage_01_prepare_base_model: ======================================================================]
# [2025-11-13 12:13:50,270: INFO: stage_01_prepare_base_model:
# >>> Step 1: Load Base Model (MobileNetV2)]
# [2025-11-13 12:13:50,272: INFO: stage_01_prepare_base_model: Loading MobileNetV2 base model...]
# [2025-11-13 12:13:52,661: INFO: stage_01_prepare_base_model: ✓ Base model saved at: artifacts\prepare_base_model\base_model.keras]
# [2025-11-13 12:13:52,667: INFO: stage_01_prepare_base_model: ✓ Model: MobileNetV2]
# [2025-11-13 12:13:52,671: INFO: stage_01_prepare_base_model: ✓ Input shape: [224, 224, 3]]
# [2025-11-13 12:13:52,676: INFO: stage_01_prepare_base_model: ✓ Total layers: 154]
# [2025-11-13 12:13:52,684: INFO: stage_01_prepare_base_model: ✓ Trainable params: 2,257,984]
# [2025-11-13 12:13:52,688: INFO: stage_01_prepare_base_model:
# >>> Step 2: Add Custom Classification Head]
# [2025-11-13 12:13:52,698: INFO: stage_01_prepare_base_model: Updating base model with custom head...]
# [2025-11-13 12:13:52,700: INFO: stage_01_prepare_base_model: Freezing all base model layers...]
# [2025-11-13 12:13:52,710: INFO: stage_01_prepare_base_model: ✓ Trainable parameters: 0]
# [2025-11-13 12:13:52,715: INFO: stage_01_prepare_base_model: ✓ Non-trainable parameters: 2,257,984]
# [2025-11-13 12:13:52,720: INFO: stage_01_prepare_base_model: Adding custom classification head...]
# [2025-11-13 12:13:52,767: INFO: stage_01_prepare_base_model: Compiling model...]
# [2025-11-13 12:13:52,791: INFO: stage_01_prepare_base_model: ✓ Model compiled successfully]
# [2025-11-13 12:13:52,797: INFO: stage_01_prepare_base_model: ✓ Optimizer: Adam (lr=0.001)]
# [2025-11-13 12:13:52,803: INFO: stage_01_prepare_base_model: ✓ Loss: Categorical Crossentropy]
# [2025-11-13 12:13:52,809: INFO: stage_01_prepare_base_model: ✓ Metrics: Accuracy, Precision, Recall]
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 180, in initiate_base_model_preparation
#     self.get_base_model()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 39, in get_base_model
#     logger.info(f"Base model saved at: {self.config.base_model_path}")
# Message: '✓ Base model saved at: artifacts\\prepare_base_model\\base_model.keras'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 180, in initiate_base_model_preparation
#     self.get_base_model()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 42, in get_base_model
#     logger.info(f"Model: MobileNetV2")
# Message: '✓ Model: MobileNetV2'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 180, in initiate_base_model_preparation
#     self.get_base_model()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 43, in get_base_model
#     logger.info(f"Input shape: {self.config.params_image_size}")
# Message: '✓ Input shape: [224, 224, 3]'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 180, in initiate_base_model_preparation
#     self.get_base_model()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 44, in get_base_model
#     logger.info(f"Total layers: {len(self.model.layers)}")
# Message: '✓ Total layers: 154'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 180, in initiate_base_model_preparation
#     self.get_base_model()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 45, in get_base_model
#     logger.info(f"Trainable params: {self.model.count_params():,}")
# Message: '✓ Trainable params: 2,257,984'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 184, in initiate_base_model_preparation
#     self.update_base_model()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 145, in update_base_model
#     self.full_model = self._prepare_full_model(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 82, in _prepare_full_model
#     logger.info(f"Trainable parameters: {trainable_count:,}")
# Message: '✓ Trainable parameters: 0'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 184, in initiate_base_model_preparation
#     self.update_base_model()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 145, in update_base_model
#     self.full_model = self._prepare_full_model(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 83, in _prepare_full_model
#     logger.info(f"Non-trainable parameters: {non_trainable_count:,}")
# Message: '✓ Non-trainable parameters: 2,257,984'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 184, in initiate_base_model_preparation
#     self.update_base_model()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 145, in update_base_model
#     self.full_model = self._prepare_full_model(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 125, in _prepare_full_model
#     logger.info("Model compiled successfully")
# Message: '✓ Model compiled successfully'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 61: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
# ...
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 194, in initiate_base_model_preparation
#     logger.info(f"  Class Names: glioma_tumor, meningioma_tumor, no_tumor, pituitary_tumor")
# Message: '  → Class Names: glioma_tumor, meningioma_tumor, no_tumor, pituitary_tumor'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2192' in position 63: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 195, in initiate_base_model_preparation
#     logger.info(f"  Base Model: Frozen (Transfer Learning)")
# Message: '  → Base Model: Frozen (Transfer Learning)'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2192' in position 63: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 196, in initiate_base_model_preparation
#     logger.info(f"  Learning Rate: {self.config.params_learning_rate}")
# Message: '  → Learning Rate: 0.001'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2192' in position 63: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2040, in _run_once
#     handle._run()
#   File "C:\Users\shipr\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\brain\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\shipr\AppData\Local\Temp\ipykernel_4176\839453329.py", line 10, in <module>
#     prepare_base_model.main()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\pipeline\__init__.py", line 62, in main
#     prepare_base_model.initiate_base_model_preparation()
#   File "c:\Users\shipr\OneDrive\Documents\project\Brain-tumor-Classification\BT_Classification\components\stage_01_prepare_base_model.py", line 197, in initiate_base_model_preparation
#     logger.info(f"  Model Ready for Training!")
# Message: '  → Model Ready for Training!'
# Arguments: ()
